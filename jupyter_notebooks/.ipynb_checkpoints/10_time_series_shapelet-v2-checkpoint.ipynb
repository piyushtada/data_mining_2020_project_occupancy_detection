# %% [markdown]
# **Author:** [Riccardo Guidotti](http://kdd.isti.cnr.it/people/riccardo-guidotti)
# **Python version:**  3.x

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from collections import defaultdict

# %% [markdown]
# # Data Preparation

# %%
dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m')
df = pd.read_csv('AirPassengers.csv', parse_dates=True, index_col='Month', date_parser=dateparse)
df.head()
# Out:
# /Users/piyush2017/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   """Entry point for launching an IPython kernel.
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
ts = df['#Passengers']
index = pd.date_range(start=ts.index[0], end=ts.index[len(ts)-1], freq='MS')
ts = pd.Series(ts.values, index)
plt.plot(ts)
plt.show()

# %%
from pyts.datasets import make_cylinder_bell_funnel

# %%
X, y = make_cylinder_bell_funnel(n_samples=12, random_state=42)

plt.figure()
for i, classe in enumerate(['cylinder', 'bell', 'funnel']):
    plt.subplot(3, 1, i + 1)
    for x in X[y == i]:
        plt.plot(x, color='C0', linewidth=0.9)
    plt.title('Class: {}'.format(classe), fontsize=16)

plt.tight_layout()
plt.subplots_adjust(hspace=0.4)
plt.show()

# %%
X.shape
# Out:
# (12, 128)

# %% [markdown]
# # Shapelet Discovery

# %% [markdown]
# https://tslearn.readthedocs.io/en/latest/gen_modules/shapelets/tslearn.shapelets.ShapeletModel.html#tslearn.shapelets.ShapeletModel
#
# https://www.kaggle.com/group16/shapelets

# %%
from keras.optimizers import Adagrad
from tslearn.shapelets import ShapeletModel
from tslearn.shapelets import grabocka_params_to_shapelet_size_dict

from tslearn.preprocessing import TimeSeriesScalerMinMax
# Out:
# Using TensorFlow backend.
# /Users/piyush2017/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/piyush2017/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/piyush2017/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/piyush2017/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/piyush2017/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/piyush2017/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/piyush2017/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.cluster.k_means_ module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.cluster. Anything that cannot be imported from sklearn.cluster is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
n_ts, ts_sz = X.shape
n_classes = len(set(y))

# Set the number of shapelets per size as done in the original paper
shapelet_sizes = grabocka_params_to_shapelet_size_dict(n_ts=n_ts,
                                                       ts_sz=ts_sz,
                                                       n_classes=n_classes,
                                                       l=0.1,
                                                       r=1)

print('n_ts', n_ts)
print('ts_sz', ts_sz)
print('n_classes', n_classes)
print('shapelet_sizes', shapelet_sizes)
# Out:
# n_ts 12
# ts_sz 128
# n_classes 3
# shapelet_sizes {12: 3}

# %%
# Define the model using parameters provided by the authors (except that we use
# fewer iterations here)
shp_clf = ShapeletModel(n_shapelets_per_size=shapelet_sizes,
                        optimizer="sgd",
                        weight_regularizer=.01,
                        max_iter=200,
                        verbose=1)

# %%
shp_clf.fit(X, y)
# Out:
# WARNING:tensorflow:From /Users/piyush2017/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/piyush2017/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /Users/piyush2017/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Epoch 1/200
# 12/12 [==============================] - 0s 25ms/step - loss: 0.9404 - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.9167
# Epoch 2/200
# 12/12 [==============================] - 0s 218us/step - loss: 0.9380 - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.9143
# Epoch 3/200
# 12/12 [==============================] - 0s 334us/step - loss: 0.9356 - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.9119
# Epoch 4/200
# 12/12 [==============================] - 0s 841us/step - loss: 0.9334 - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.9096
# Epoch 5/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.9311 - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.9074
# Epoch 6/200
# 12/12 [==============================] - 0s 260us/step - loss: 0.9289 - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.9052
# Epoch 7/200
# 12/12 [==============================] - 0s 893us/step - loss: 0.9268 - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.9031
# Epoch 8/200
# 12/12 [==============================] - 0s 366us/step - loss: 0.9247 - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.9010
# Epoch 9/200
# 12/12 [==============================] - 0s 355us/step - loss: 0.9226 - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.
- categorical_accuracy: 0.6667 - categorical_crossentropy: 0.7266
# Epoch 192/200
# 12/12 [==============================] - 0s 293us/step - loss: 0.7511 - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.7261
# Epoch 193/200
# 12/12 [==============================] - 0s 250us/step - loss: 0.7506 - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.7255
# Epoch 194/200
# 12/12 [==============================] - 0s 407us/step - loss: 0.7501 - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.7250
# Epoch 195/200
# 12/12 [==============================] - 0s 354us/step - loss: 0.7496 - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.7245
# Epoch 196/200
# 12/12 [==============================] - 0s 317us/step - loss: 0.7490 - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.7239
# Epoch 197/200
# 12/12 [==============================] - 0s 248us/step - loss: 0.7485 - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.7234
# Epoch 198/200
# 12/12 [==============================] - 0s 330us/step - loss: 0.7480 - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.7229
# Epoch 199/200
# 12/12 [==============================] - 0s 376us/step - loss: 0.7475 - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.7223
# Epoch 200/200
# 12/12 [==============================] - 0s 321us/step - loss: 0.7470 - categorical_accuracy: 0.6667 - categorical_crossentropy: 0.7218
# ShapeletModel(batch_size=256, max_iter=200, n_shapelets_per_size={12: 3},
#               optimizer='sgd', random_state=None, shapelet_length=0.15,
#               total_lengths=3, verbose=1, verbose_level=None,
#               weight_regularizer=0.01)

# %%
from sklearn.metrics import accuracy_score

# %%
predicted_labels = shp_clf.predict(X)
print("Correct classification rate:", accuracy_score(y, predicted_labels))
# Out:
# 12/12 [==============================] - 0s 4ms/step
# Correct classification rate: 0.6666666666666666

# %%
predicted_locations = shp_clf.locate(X)
# Out:
# 12/12 [==============================] - 0s 4ms/step
# /Users/piyush2017/opt/anaconda3/lib/python3.7/site-packages/tslearn/utils.py:63: UserWarning: 2-Dimensional data passed. Assuming these are 12 1-dimensional timeseries
#   '{} 1-dimensional timeseries'.format(X.shape[0]))

# %%
ts_id = 0
plt.figure()
n_shapelets = sum(shapelet_sizes.values())
plt.title("Example locations of shapelet matches "
          "(%d shapelets extracted)".format(n_shapelets))

plt.plot(X[ts_id].ravel())
for idx_shp, shp in enumerate(shp_clf.shapelets_):
    t0 = predicted_locations[ts_id, idx_shp]
    plt.plot(np.arange(t0, t0 + len(shp)), shp, linewidth=2)

# %% [markdown]
# ## Shaplet Discovery 2

# %%
from shapelets_lts.classification import LtsShapeletClassifier

# %% [markdown]
# https://github.com/mohaseeb/shaplets-python

# %%
shp_clf = LtsShapeletClassifier(
    K=10,
    R=1,
    L_min=10,
    epocs=10,
    lamda=0.01,
    eta=0.01,
    shapelet_initialization='segments_centroids',
    plot_loss=False
)
"""
:param K: number of shapelets
:param R: scales of shapelet lengths
:param L_min: minimum shapelet length
"""
# Out:
# '\n:param K: number of shapelets\n:param R: scales of shapelet lengths\n:param L_min: minimum shapelet length\n'

# %%
shp_clf.fit(X, y)
# Out:
# Network initialization ...
# Using training data to initialize shaplets
# Training ...
# Using training data for validation
# epoch=1/10 (iteration=12) loss=2.4902090259969922 validation accuracy=0.0
# epoch=2/10 (iteration=24) loss=1.7096915719714263 validation accuracy=0.08333333333333333
# epoch=3/10 (iteration=36) loss=1.4234319147335233 validation accuracy=0.08333333333333333
# epoch=4/10 (iteration=48) loss=1.3585711287010573 validation accuracy=0.08333333333333333
# epoch=5/10 (iteration=60) loss=1.362525958523573 validation accuracy=0.4166666666666667
# epoch=6/10 (iteration=72) loss=1.3820910607557537 validation accuracy=0.5
# epoch=7/10 (iteration=84) loss=1.4009333051455486 validation accuracy=0.6666666666666666
# epoch=8/10 (iteration=96) loss=1.4152341823256043 validation accuracy=0.8333333333333334
# epoch=9/10 (iteration=108) loss=1.4249937679288047 validation accuracy=0.9166666666666666
# epoch=10/10 (iteration=120) loss=1.4309969007299896 validation accuracy=0.9166666666666666
# LtsShapeletClassifier(K=10, L_min=10, R=1, alpha=-100, epocs=10, eta=0.01,
#                       lamda=0.01, plot_loss=False,
#                       shapelet_initialization='segments_centroids')

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred = shp_clf.predict(X)

print("Correct classification rate:", accuracy_score(y, y_pred))
# Out:
# Correct classification rate: 0.9166666666666666

# %%
# retrieve the learnt shapelets
shapelets = shp_clf.get_shapelets()

# and plot sample shapelets
from shapelets_lts.util import plot_sample_shapelets
plot_sample_shapelets(shapelets=shapelets, sample_size=36)

# %%
len(shapelets)
# Out:
# 10

# %%
shapelets
# Out:
# [array([0.23370554, 0.13217634, 0.02816864, 0.140096  , 0.17600798,
#         1.30964948, 2.55779987, 3.92470937, 4.99506669, 4.85870712]),
#  array([-0.55658919,  0.07366671,  0.00389179, -0.22999791,  0.01700663,
#         -0.24739515,  0.27330116, -0.17707791, -0.10301876,  0.1338666 ]),
#  array([0.16649048, 0.31442066, 1.77619624, 3.4731048 , 4.87082007,
#         4.88584638, 4.59882923, 4.4909403 , 4.58350311, 4.57516147]),
#  array([ 5.14961959,  5.23253536,  3.61817805,  2.1004156 ,  0.59508371,
#          0.07081947,  0.01709801,  0.02354425,  0.09213664, -0.01428031]),
#  array([3.30522457, 3.31192331, 3.33661301, 3.37209966, 3.30645963,
#         3.34836524, 3.31261211, 3.33834612, 3.27265581, 3.24642578]),
#  array([ 0.89656311, -0.10716583,  0.05553002,  0.34182052,  0.07189728,
#          0.40306559, -0.1650966 ,  0.4246405 ,  0.30684154,  0.14368332]),
#  array([5.0720457 , 4.42433374, 4.68992089, 4.92733899, 4.66156503,
#         5.30514193, 5.17297636, 4.93437114, 5.19513713, 4.57422379]),
#  array([ 4.9513527 ,  5.05992827,  5.04062642,  5.17533764,  5.40955448,
#          4.53513872,  2.95246459,  1.47595141,  0.05451269, -0.0251282 ]),
#  array([1.64184114, 1.6721183 , 1.67617102, 1.63509733, 1.61573297,
#         1.61782862, 1.60315194, 1.56061419, 1.66217649, 1.713887  ]),
#  array([4.50762137, 5.26682123, 5.05856632, 4.8141196 , 4.9790305 ,
#         4.35602205, 4.56992073, 4.88254813, 4.55686777, 5.0812554 ])]

# %% [markdown]
# ## Shaplet Discovery 3

# %%
from pyts.transformation import ShapeletTransform

# %% [markdown]
# https://pyts.readthedocs.io/en/stable/generated/pyts.transformation.ShapeletTransform.html#pyts.transformation.ShapeletTransform

# %%
st = ShapeletTransform(n_shapelets=3, window_sizes=[8])
st.fit(X, y)
# Out:
# ShapeletTransform(criterion='mutual_info', n_jobs=None, n_shapelets=3,
#                   random_state=None, remove_similar=True, sort=False, verbose=0,
#                   window_sizes=[8], window_steps=None)

# %%
len(st.shapelets_)
# Out:
# 3

# %%
st.shapelets_
# Out:
# array([[3.32244276, 2.08622399, 2.34982847, 1.53841713, 2.98657494,
#         1.31505755, 3.5554072 , 5.0680106 ],
#        [0.59797821, 3.69513016, 3.86013371, 1.36924283, 3.22780396,
#         1.42936456, 2.12458586, 1.04881421],
#        [3.16374059, 4.28167516, 1.31811493, 1.60277031, 2.19599592,
#         1.77094864, 1.71521399, 0.37938582]])

# %%
for s in st.shapelets_:
    plt.plot(s)

plt.show()

# %% [markdown]
# The indices for the corresponding shapelets in the training set. The first column consists of the indices of the samples. The second column consists of the starting indices (included) of the shapelets. The third column consists of the ending indices (excluded) of the shapelets.

# %%
st.indices_
# Out:
# array([[11, 66, 74],
#        [ 2, 65, 73],
#        [ 2, 55, 63]])

# %%
X[2][55:63]
# Out:
# array([3.16374059, 4.28167516, 1.31811493, 1.60277031, 2.19599592,
#        1.77094864, 1.71521399, 0.37938582])

# %%
st.scores_
# Out:
# array([0.81630592, 0.82821068, 0.82821068])

# %% [markdown]
# ## Shaplet Discovery 4

# %%
from pyts.classification import LearningShapelets

# %% [markdown]
# https://pyts.readthedocs.io/en/stable/generated/pyts.classification.LearningShapelets.html#pyts.classification.LearningShapelets

# %%
shp_clf = LearningShapelets(random_state=42, tol=0.01)

# %%
shp_clf.fit(X, y)
# Out:
# LearningShapelets(C=1000, alpha=-100, class_weight=None, fit_intercept=True,
#                   intercept_scaling=1.0, learning_rate=1.0, max_iter=1000,
#                   min_shapelet_length=0.1, multi_class='multinomial',
#                   n_jobs=None, n_shapelets_per_size=0.2, penalty='l2',
#                   random_state=42, shapelet_scale=3, tol=0.01, verbose=0)

# %%
len(shp_clf.shapelets_[0])
# Out:
# 78

# %%
from pyts.utils import windowed_view

# %%
# Select three shapelets
sel_shapelets = np.asarray([shp_clf.shapelets_[0, 0], 
                        shp_clf.shapelets_[0, 1], 
                        shp_clf.shapelets_[0, 2]])

# %%
plt.plot(sel_shapelets[0])
plt.plot(sel_shapelets[1])
plt.plot(sel_shapelets[2])

plt.show()

# %%
# Derive the distances between the time series and a shapelets
shapelet_size = sel_shapelets.shape[1]
X_window = windowed_view(X, window_size=shapelet_size, window_step=1)
X_dist = np.mean((X_window[:, :, None] - sel_shapelets[None, :]) ** 2, axis=3).min(axis=1)

# %%
X_dist
# Out:
# array([[0.59737952, 1.28796807, 0.50621251],
#        [0.63559338, 0.4301728 , 3.68841088],
#        [0.34604746, 0.70732199, 0.83927128],
#        [0.42395593, 0.3064432 , 2.19689706],
#        [0.31660035, 0.64211339, 0.61607883],
#        [0.85146216, 1.08379101, 0.65999991],
#        [0.36735134, 0.2589913 , 1.02243509],
#        [0.44191696, 0.46102256, 2.86596557],
#        [0.67295427, 0.66323123, 0.69942267],
#        [0.50436926, 0.51245606, 2.60002204],
#        [0.66321681, 0.64157927, 0.17103595],
#        [0.21831585, 1.27528248, 1.03761191]])

# %%
np.mean(X_dist[y == 0], axis=0)
# Out:
# array([0.50145888, 0.42752366, 2.83782389])

# %%
np.mean(X_dist[y == 1], axis=0)
# Out:
# array([0.51483316, 0.91610453, 0.75327833])

# %%
np.mean(X_dist[y == 2], axis=0)
# Out:
# array([0.49349878, 0.72396516, 0.63473871])

# %% [markdown]
# # Matrix Profile

# %% [markdown]
# https://github.com/target/matrixprofile-ts
#
# https://github.com/TDAmeritrade/stumpy

# %%
from matrixprofile import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-43-cbe3f6ed5a15> in <module>
# ----> 1 from matrixprofile import *
#
# ModuleNotFoundError: No module named 'matrixprofile'

# %%
plt.plot(ts)
plt.show()

# %%
w = 12
mp, mpi = matrixProfile.stomp(ts.values, w)

plt.plot(mp)
plt.show()

# %%
window = 12
ts_log_mov_diff = pd.Series(np.log(ts) - np.log(ts).rolling(window, center=False).mean(), index=ts.index)

plt.plot(ts_log_mov_diff)
plt.show()

# %%
w = 12
mp, mpi = matrixProfile.stomp(ts_log_mov_diff.values[11:], w)

plt.plot(mp)
plt.show()

# %%
w = 3
mp, mpi = matrixProfile.stomp(ts.values, w)

plt.plot(mp)
plt.show()

# %% [markdown]
# # Motif Discovery

# %%
#mp_adj = np.append(mp[0],np.zeros(m-1)+np.nan)

mo, mod  = motifs.motifs(ts.values, (mp, mpi), max_motifs=5)

# %% [markdown]
# Parameters
# - max_motifs: stop finding new motifs once we have max_motifs
# - radius: For each motif found, find neighbors that are within radius*motif_mp of the first.
# - n_neighbors: number of neighbors from the first to find. If it is None, find all.
# - ex_zone: minimum distance between indices for after each subsequence is identified. Defaults to m/2 where m is the subsequence length. If ex_zone = 0, only the found index is exclude, if ex_zone = 1 then if idx is found as a motif idx-1, idx, idx+1 are excluded.

# %% [markdown]
# Returns
# The function returns a tuple (top_motifs, distances) which are lists of the same length.
#
# - top_motifs: This is a list of the indices found for each motif. The first index is the nth motif followed by all nearest neighbors found sorted by distances.
# - distances: Minimum Matrix profile value for each motif set.

# %%
mo

# %%
mod

# %%
plt.plot(ts.values)
colors = ['r', 'g', 'k', 'b', 'y'][:len(mo)]
for m, d, c in zip(mo, mod, colors):
    for i in m:
        m_shape = ts.values[i:i+w]
        plt.plot(range(i,i+w), m_shape, color=c, lw=3)

plt.show()

# %%
for m, d, c in zip(mo, mod, colors):
    for i in m:
        m_shape = ts.values[i:i+w]
        plt.plot(range(i,i+w), m_shape, color=c, lw=3)
    plt.show()

# %% [markdown]
# # Anomaly Discovery

# %%
from matrixprofile.discords import discords

# %% [markdown]
# Parameters
# - mp: matrix profile numpy array
# - k: the number of discords to discover
# - ex_zone: the number of samples to exclude and set to Inf on either side of a found discord

# %% [markdown]
# Returns
#  - a list of indexes represent the discord starting locations. MaxInt indicates there were no more discords that could be found due to too many exclusions or profile being too small. Discord start indices are sorted by highest matrix profile value.

# %%
anoms = discords(mp, ex_zone=3, k=5)

# %%
anoms

# %%
plt.plot(ts.values)
colors = ['r', 'g', 'k', 'b', 'y'][:len(mo)]
for a, c in zip(anoms, colors):
    a_shape = ts.values[a:a+w]
    plt.plot(range(a, a+w), a_shape, color=c, lw=3)

plt.show()
