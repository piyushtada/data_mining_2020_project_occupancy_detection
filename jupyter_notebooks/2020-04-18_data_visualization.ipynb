# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(20,10))

# %%
# import csv

# with open('/Users/piyush2017/Downloads/occupancy_data (1)/datatraining.txt', 'r') as in_file:
#     stripped = (line.strip() for line in in_file)
#     lines = (line.split(",") for line in stripped if line)
#     with open('/Users/piyush2017/Downloads/occupancy_data (1)/datatraining1.csv', 'w') as out_file:
#         writer = csv.writer(out_file)
#         #writer.writerow(('title', 'intro'))
#         writer.writerows(lines)

# %%
#dateparse = lambda dates: pd.datetime.strptime(dates, '%d/%m/%y %H:%M:%S')
df = pd.read_csv('/Users/piyush2017/Downloads/occupancy_data (1)/datatraining_copy.csv')
columns2remove = ['Number'] #eliminiamo perchè non ci servono
df.date = pd.to_datetime(df.date)
df.drop(columns2remove, inplace=True, axis=1)
df.head()
# Out:
#                  date  Temperature  Humidity  Light     CO2  HumidityRatio  \
# 0 2015-02-04 17:51:00        23.18   27.2720  426.0  721.25       0.004793
# 1 2015-02-04 17:51:59        23.15   27.2675  429.5  714.00       0.004783
# 2 2015-02-04 17:53:00        23.15   27.2450  426.0  713.50       0.004779
# 3 2015-02-04 17:54:00        23.15   27.2000  426.0  708.25       0.004772
# 4 2015-02-04 17:55:00        23.10   27.2000  426.0  704.50       0.004757
#
#    Occupancy
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
df.tail()
# Out:
#                     date  Temperature  Humidity  Light         CO2  \
# 8138 2015-02-10 09:29:00        21.05   36.0975  433.0  787.250000
# 8139 2015-02-10 09:29:59        21.05   35.9950  433.0  789.500000
# 8140 2015-02-10 09:30:59        21.10   36.0950  433.0  798.500000
# 8141 2015-02-10 09:32:00        21.10   36.2600  433.0  820.333333
# 8142 2015-02-10 09:33:00        21.10   36.2000  447.0  821.000000
#
#       HumidityRatio  Occupancy
# 8138       0.005579          1
# 8139       0.005563          1
# 8140       0.005596          1
# 8141       0.005621          1
# 8142       0.005612          1

# %%
df.date.max() - df.date.min()
# Out:
# Timedelta('5 days 15:42:00')

# %% [markdown]
# As you can see from above that we can see the max and min value of date and time type format as you can see below date column is now special datetime format

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8143 entries, 0 to 8142
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           8143 non-null   datetime64[ns]
#  1   Temperature    8143 non-null   float64
#  2   Humidity       8143 non-null   float64
#  3   Light          8143 non-null   float64
#  4   CO2            8143 non-null   float64
#  5   HumidityRatio  8143 non-null   float64
#  6   Occupancy      8143 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 445.4 KB

# %% [markdown]
# This dt.round has may more things that you can do https://www.youtube.com/watch?v=yCgJGsg0Xa4

# %%
df.date = df.date.dt.round("T")

# %% [markdown]
# I wrote T because for seconds this is https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#timeseries-offset-aliases

# %%
df.tail()
# Out:
#                     date  Temperature  Humidity  Light         CO2  \
# 8138 2015-02-10 09:29:00        21.05   36.0975  433.0  787.250000
# 8139 2015-02-10 09:29:59        21.05   35.9950  433.0  789.500000
# 8140 2015-02-10 09:30:59        21.10   36.0950  433.0  798.500000
# 8141 2015-02-10 09:32:00        21.10   36.2600  433.0  820.333333
# 8142 2015-02-10 09:33:00        21.10   36.2000  447.0  821.000000
#
#       HumidityRatio  Occupancy
# 8138       0.005579          1
# 8139       0.005563          1
# 8140       0.005596          1
# 8141       0.005621          1
# 8142       0.005612          1

# %%
df[df.index == 0]
# Out:
#                  date  Temperature  Humidity  Light     CO2  HumidityRatio  \
# 0 2015-02-04 17:51:00        23.18    27.272  426.0  721.25       0.004793
#
#    Occupancy
# 0          1

# %%
df.to_csv("/Users/piyush2017/Downloads/occupancy_data (1)/datatraining_fix_min.csv",index=False)

# %% [markdown]
# # getting fixed data

# %%
dff = pd.read_csv("/Users/piyush2017/Downloads/occupancy_data (1)/datatraining_fix_min.csv")

# %%
dff.head()
# Out:
#                   date  Temperature  Humidity  Light     CO2  HumidityRatio  \
# 0  2015-02-04 17:51:00        23.18   27.2720  426.0  721.25       0.004793
# 1  2015-02-04 17:52:00        23.15   27.2675  429.5  714.00       0.004783
# 2  2015-02-04 17:53:00        23.15   27.2450  426.0  713.50       0.004779
# 3  2015-02-04 17:54:00        23.15   27.2000  426.0  708.25       0.004772
# 4  2015-02-04 17:55:00        23.10   27.2000  426.0  704.50       0.004757
#
#    Occupancy
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
dff.set_index('date', inplace=True)

# %%
dff.head()
# Out:
#                      Temperature  Humidity  Light     CO2  HumidityRatio  \
# date
# 2015-02-04 17:51:00        23.18   27.2720  426.0  721.25       0.004793
# 2015-02-04 17:52:00        23.15   27.2675  429.5  714.00       0.004783
# 2015-02-04 17:53:00        23.15   27.2450  426.0  713.50       0.004779
# 2015-02-04 17:54:00        23.15   27.2000  426.0  708.25       0.004772
# 2015-02-04 17:55:00        23.10   27.2000  426.0  704.50       0.004757
#
#                      Occupancy
# date
# 2015-02-04 17:51:00          1
# 2015-02-04 17:52:00          1
# 2015-02-04 17:53:00          1
# 2015-02-04 17:54:00          1
# 2015-02-04 17:55:00          1

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8143 entries, 2015-02-04 17:51:00 to 2015-02-10 09:33:00
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Temperature    8143 non-null   float64
#  1   Humidity       8143 non-null   float64
#  2   Light          8143 non-null   float64
#  3   CO2            8143 non-null   float64
#  4   HumidityRatio  8143 non-null   float64
#  5   Occupancy      8143 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 445.3+ KB

# %%
dff.asfreq("T")
# Out:
#                      Temperature  Humidity  Light         CO2  HumidityRatio  \
# date
# 2015-02-04 17:51:00        23.18   27.2720  426.0  721.250000       0.004793
# 2015-02-04 17:52:00        23.15   27.2675  429.5  714.000000       0.004783
# 2015-02-04 17:53:00        23.15   27.2450  426.0  713.500000       0.004779
# 2015-02-04 17:54:00        23.15   27.2000  426.0  708.250000       0.004772
# 2015-02-04 17:55:00        23.10   27.2000  426.0  704.500000       0.004757
# ...                          ...       ...    ...         ...            ...
# 2015-02-10 09:29:00        21.05   36.0975  433.0  787.250000       0.005579
# 2015-02-10 09:30:00        21.05   35.9950  433.0  789.500000       0.005563
# 2015-02-10 09:31:00        21.10   36.0950  433.0  798.500000       0.005596
# 2015-02-10 09:32:00        21.10   36.2600  433.0  820.333333       0.005621
# 2015-02-10 09:33:00        21.10   36.2000  447.0  821.000000       0.005612
#
#                      Occupancy
# date
# 2015-02-04 17:51:00          1
# 2015-02-04 17:52:00          1
# 2015-02-04 17:53:00          1
# 2015-02-04 17:54:00          1
# 2015-02-04 17:55:00          1
# ...                        ...
# 2015-02-10 09:29:00          1
# 2015-02-10 09:30:00          1
# 2015-02-10 09:31:00          1
# 2015-02-10 09:32:00          1
# 2015-02-10 09:33:00          1
#
# [8143 rows x 6 columns]

# %%
dff.plot(subplots=True, figsize = (15,8))
plt.plot()
plt.savefig("alltheday.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-82ef87c7342c> in <module>
#       1 dff.plot(subplots=True, figsize = (15,8))
#       2 plt.title("fuchk yo")
# ----> 3 plt.clabel("what does it do")
#       4 plt.plot()
#       5 plt.savefig("alltheday.png")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in clabel(CS, *args, **kwargs)
#    2498 @docstring.copy(Axes.clabel)
#    2499 def clabel(CS, *args, **kwargs):
# -> 2500     return gca().clabel(CS, *args, **kwargs)
#    2501
#    2502
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in clabel(self, CS, *args, **kwargs)
#    6434
#    6435     def clabel(self, CS, *args, **kwargs):
# -> 6436         return CS.clabel(*args, **kwargs)
#    6437     clabel.__doc__ = mcontour.ContourSet.clabel.__doc__
#    6438
#
# AttributeError: 'str' object has no attribute 'clabel'

# %%
dff.asfreq("T", how={'2015-02-04 00:00:00','2015-02-05 00:00:00'})
# Out:
#                      Temperature  Humidity  Light         CO2  HumidityRatio  \
# date
# 2015-02-04 17:51:00        23.18   27.2720  426.0  721.250000       0.004793
# 2015-02-04 17:52:00        23.15   27.2675  429.5  714.000000       0.004783
# 2015-02-04 17:53:00        23.15   27.2450  426.0  713.500000       0.004779
# 2015-02-04 17:54:00        23.15   27.2000  426.0  708.250000       0.004772
# 2015-02-04 17:55:00        23.10   27.2000  426.0  704.500000       0.004757
# ...                          ...       ...    ...         ...            ...
# 2015-02-10 09:29:00        21.05   36.0975  433.0  787.250000       0.005579
# 2015-02-10 09:30:00        21.05   35.9950  433.0  789.500000       0.005563
# 2015-02-10 09:31:00        21.10   36.0950  433.0  798.500000       0.005596
# 2015-02-10 09:32:00        21.10   36.2600  433.0  820.333333       0.005621
# 2015-02-10 09:33:00        21.10   36.2000  447.0  821.000000       0.005612
#
#                      Occupancy
# date
# 2015-02-04 17:51:00          1
# 2015-02-04 17:52:00          1
# 2015-02-04 17:53:00          1
# 2015-02-04 17:54:00          1
# 2015-02-04 17:55:00          1
# ...                        ...
# 2015-02-10 09:29:00          1
# 2015-02-10 09:30:00          1
# 2015-02-10 09:31:00          1
# 2015-02-10 09:32:00          1
# 2015-02-10 09:33:00          1
#
# [8143 rows x 6 columns]

# %%
df9 = dff[(dff.index >= '2015-02-05 00:00:00') & (dff.index < '2015-02-06 00:00:00')]

# %%
df9.head()
# Out:
#                      Temperature  Humidity  Light         CO2  HumidityRatio  \
# date
# 2015-02-05 00:00:00       21.245    25.245    0.0  456.500000       0.003938
# 2015-02-05 00:01:00       21.245    25.245    0.0  458.500000       0.003938
# 2015-02-05 00:02:00       21.260    25.260    0.0  459.666667       0.003944
# 2015-02-05 00:03:00       21.245    25.245    0.0  464.000000       0.003938
# 2015-02-05 00:04:00       21.245    25.200    0.0  465.000000       0.003931
#
#                      Occupancy
# date
# 2015-02-05 00:00:00          0
# 2015-02-05 00:01:00          0
# 2015-02-05 00:02:00          0
# 2015-02-05 00:03:00          0
# 2015-02-05 00:04:00          0

# %%
df9.tail()
# Out:
#                      Temperature  Humidity  Light    CO2  HumidityRatio  \
# date
# 2015-02-05 23:55:00      20.2900   21.2900    0.0  439.5       0.003127
# 2015-02-05 23:56:00      20.2225   21.2225    0.0  445.0       0.003104
# 2015-02-05 23:57:00      20.2000   21.2000    0.0  442.5       0.003097
# 2015-02-05 23:58:00      20.2000   21.2000    0.0  443.5       0.003097
# 2015-02-05 23:59:00      20.2000   21.2000    0.0  444.0       0.003097
#
#                      Occupancy
# date
# 2015-02-05 23:55:00          0
# 2015-02-05 23:56:00          0
# 2015-02-05 23:57:00          0
# 2015-02-05 23:58:00          0
# 2015-02-05 23:59:00          0

# %% [markdown]
# here df9 only have values from date 5 feb 2015 all the values in that date now we will save this data in trainingdata_2015-02-05.csv so we can use it for doing one day analysis

# %%
df9.to_csv("/Users/piyush2017/Downloads/occupancy_data (1)/trainingdata_2015-02-05.csv")

# %%
df9.asfreq("H")
# Out:
#                      Temperature  Humidity  Light  CO2  HumidityRatio  \
# date
# 2015-02-05 00:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 01:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 02:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 03:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 04:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 05:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 06:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 07:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 08:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 09:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 10:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 11:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 12:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 13:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 14:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 15:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 16:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 17:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 18:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 19:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 20:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 21:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 22:00:00          NaN       NaN    NaN  NaN            NaN
# 2015-02-05 23:00:00          NaN       NaN    NaN  NaN            NaN
#
#                      Occupancy
# date
# 2015-02-05 00:00:00        NaN
# 2015-02-05 01:00:00        NaN
# 2015-02-05 02:00:00        NaN
# 2015-02-05 03:00:00        NaN
# 2015-02-05 04:00:00        NaN
# 2015-02-05 05:00:00        NaN
# 2015-02-05 06:00:00        NaN
# 2015-02-05 07:00:00        NaN
# 2015-02-05 08:00:00        NaN
# 2015-02-05 09:00:00        NaN
# 2015-02-05 10:00:00        NaN
# 2015-02-05 11:00:00        NaN
# 2015-02-05 12:00:00        NaN
# 2015-02-05 13:00:00        NaN
# 2015-02-05 14:00:00        NaN
# 2015-02-05 15:00:00        NaN
# 2015-02-05 16:00:00        NaN
# 2015-02-05 17:00:00        NaN
# 2015-02-05 18:00:00        NaN
# 2015-02-05 19:00:00        NaN
# 2015-02-05 20:00:00        NaN
# 2015-02-05 21:00:00        NaN
# 2015-02-05 22:00:00        NaN
# 2015-02-05 23:00:00        NaN

# %%
df9.plot(subplots=True, figsize=(20,10))
plt.show()

# %%
dff.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a21424690>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a213d52d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a20cf9110>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a21800d10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a20aed050>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a20ab9410>],
#       dtype=object)

# %%
dff.index.dt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-a8ea675a070d> in <module>
# ----> 1 dff.index.dt
#
# AttributeError: 'DatetimeIndex' object has no attribute 'dt'

# %%
dff.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-89c332ec0aa6> in <module>
#       1 dff.plot()
# ----> 2 plt.show()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in _fetch_figure_metadata(fig)
#     179         # the background is transparent
#     180         ticksLight = _is_light([label.get_color()
# --> 181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
#     183                                 for label in axis.get_ticklabels()])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in <listcomp>(.0)
#     181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
# --> 183                                 for label in axis.get_ticklabels()])
#     184         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     185             # there are one or more tick labels, all with the same lightness
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1294         if minor:
#    1295             return self.get_minorticklabels()
# -> 1296         return self.get_majorticklabels()
#    1297
#    1298     def get_majorticklines(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1250     def get_majorticklabels(self):
#    1251         'Return a list of Text instances for the major ticklabels.'
# -> 1252         ticks = self.get_major_ticks()
#    1253         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1254         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1405         'Get the tick instances; grow as necessary.'
#    1406         if numticks is None:
# -> 1407             numticks = len(self.get_majorticklocs())
#    1408
#    1409         while len(self.majorTicks) < numticks:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_majorticklocs(self)
#    1322     def get_majorticklocs(self):
#    1323         """Get the array of major tick locations in data coordinates."""
# -> 1324         return self.major.locator()
#    1325
#    1326     def get_minorticklocs(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/dates.py in __call__(self)
#    1426     def __call__(self):
#    1427         'Return the locations of the ticks'
# -> 1428         self.refresh()
#    1429         return self._locator()
#    1430
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/dates.py in refresh(self)
#    1446     def refresh(self):
#    1447         'Refresh internal information based on current limits.'
# -> 1448         dmin, dmax = self.viewlim_to_dt()
#    1449         self._locator = self.get_locator(dmin, dmax)
#    1450
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/dates.py in viewlim_to_dt(self)
#    1197                              'often happens if you pass a non-datetime '
#    1198                              'value to an axis that has datetime units'
# -> 1199                              .format(vmin))
#    1200         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1201
#
# ValueError: view limit minimum -36781.96989583334 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units

# %%
dff_minutes_oneday = dff[dff > ts_start]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-3ec352b00a9b> in <module>
# ----> 1 dff_minutes_oneday = dff[dff > ts_start]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in f(self, other)
#     786             # straight boolean comparisons we want to allow all columns
#     787             # (regardless of dtype to pass thru) See #4537 for discussion.
# --> 788             new_data = dispatch_to_series(self, other, op)
#     789             return self._construct_result(new_data)
#     790
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in dispatch_to_series(left, right, func, str_rep, axis)
#     376         # Get the appropriate array-op to apply to each block's values.
#     377         array_op = get_array_op(func, str_rep=str_rep)
# --> 378         bm = left._data.apply(array_op, right=right)
#     379         return type(left)(bm)
#     380
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     438
#     439             if callable(f):
# --> 440                 applied = b.apply(f, **kwargs)
#     441             else:
#     442                 applied = getattr(b, f)(**kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     388         """
#     389         with np.errstate(all="ignore"):
# --> 390             result = func(self.values, **kwargs)
#     391
#     392         if is_extension_array_dtype(result) and result.ndim > 1:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     254
#     255         if res_values is NotImplemented:
# --> 256             res_values = invalid_comparison(lvalues, rvalues, op)
#     257         if is_scalar(res_values):
#     258             typ = type(rvalues)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/invalid.py in invalid_comparison(left, right, op)
#      32     else:
#      33         typ = type(right).__name__
# ---> 34         raise TypeError(f"Invalid comparison between dtype={left.dtype} and {typ}")
#      35     return res_values
#      36
#
# TypeError: Invalid comparison between dtype=float64 and Timestamp

# %%
dff_minutes_oneday
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-7d65dbb5f523> in <module>
# ----> 1 dff_minutes_oneday
#
# NameError: name 'dff_minutes_oneday' is not defined

# %%
plt.figure(figsize=(20,5))
plt.plot(df_minutes_oneday.hour, df_minutes_oneday.CO2)

# %%
plt.plot(df.minute, df.Light)

# %%
df.plot(subplots=True, figsize = (20,10))
plt.show()

# %%
try:
    df.date = pd.to_datetime(df.date)
    df.set_index('date', inplace=True)
except:
    pass
df.head()
# Out:
#                      Temperature  Humidity  Light     CO2  HumidityRatio
# date
# 2015-02-04 17:51:00        23.18   27.2720  426.0  721.25       0.004793
# 2015-02-04 17:51:00        23.15   27.2675  429.5  714.00       0.004783
# 2015-02-04 17:53:00        23.15   27.2450  426.0  713.50       0.004779
# 2015-02-04 17:54:00        23.15   27.2000  426.0  708.25       0.004772
# 2015-02-04 17:55:00        23.10   27.2000  426.0  704.50       0.004757

# %%
df[df.index.duplicated()].head()
# Out:
#                      Temperature  Humidity  Light    CO2  HumidityRatio
# date
# 2015-02-04 17:51:00       23.150   27.2675  429.5  714.0       0.004783
# 2015-02-04 17:55:00       23.100   27.2000  419.0  701.0       0.004757
# 2015-02-04 17:57:00       23.100   27.2000  419.0  699.0       0.004757
# 2015-02-04 18:04:00       23.000   27.1250  419.0  686.0       0.004715
# 2015-02-04 18:08:00       22.945   27.3900    0.0  685.0       0.004745

# %%
df.asfreq(freq='D')
# Out:
#            "Number" "date"  "Temperature"  "Humidity"  "Light"  "CO2"  \
# 1970-01-01      NaN    NaN            NaN         NaN      NaN    NaN
#
#             "HumidityRatio"  "Occupancy"
# 1970-01-01              NaN          NaN

# %%
df.head()
# Out:
#   "Number"                 "date"  "Temperature"  "Humidity"  "Light"   "CO2"  \
# 0      "1"  "2015-02-04 17:51:00"          23.18     27.2720    426.0  721.25
# 1      "2"  "2015-02-04 17:51:59"          23.15     27.2675    429.5  714.00
# 2      "3"  "2015-02-04 17:53:00"          23.15     27.2450    426.0  713.50
# 3      "4"  "2015-02-04 17:54:00"          23.15     27.2000    426.0  708.25
# 4      "5"  "2015-02-04 17:55:00"          23.10     27.2000    426.0  704.50
#
#    "HumidityRatio"  "Occupancy"
# 0         0.004793            1
# 1         0.004783            1
# 2         0.004779            1
# 3         0.004772            1
# 4         0.004757            1

# %%
df.plot(subplots=True, figsize = (20,10))
plt.show()

# %%
import datetime

start = datetime.datetime.strptime("01-04-2020", "%d-%m-%Y")
end = datetime.datetime.strptime("30-04-2020", "%d-%m-%Y")
date_generated = [start + datetime.timedelta(days=x) for x in range(0, (end-start).days)]

for date in date_generated:
    print(date.strftime("%d-%m-%Y"))
# Out:
# 01-04-2020
# 02-04-2020
# 03-04-2020
# 04-04-2020
# 05-04-2020
# 06-04-2020
# 07-04-2020
# 08-04-2020
# 09-04-2020
# 10-04-2020
# 11-04-2020
# 12-04-2020
# 13-04-2020
# 14-04-2020
# 15-04-2020
# 16-04-2020
# 17-04-2020
# 18-04-2020
# 19-04-2020
# 20-04-2020
# 21-04-2020
# 22-04-2020
# 23-04-2020
# 24-04-2020
# 25-04-2020
# 26-04-2020
# 27-04-2020
# 28-04-2020
# 29-04-2020
